# %% [markdown]
# ## Предсказание вероятности смерти в позиции (x,y) в течении t сек.

# %% [markdown]
# ### Для соло GSI формата
#
# - (true/false) живы ли союзники
# - (x, y) ласт видимая позиция союзников/врагов, если ушел в ноу вижен
# - ([int/str, ...]) id/название предметов героя/союзников | для союзников надо отслеживать events, там есть сообщения о покупке предметов +- серьезрных(боотинки, дейдалус, тд)
# - ([(x, y), ...]) позиции вардов/ближайших вардов
# - (int) хп
# - (int) мана
# - (int) макс хп
# - (int) макс мана
# - (str) имя героя игрока | можно сделать id
# - ([str, ...]) имена героев союзников | можно сделать id
# - ([str, ...]) имена героев врагов | можно сделать id
# - (int) уровень
# - (int) расстояние до ближайшего союзного тавера
# - (int) расстояние до вражеского тавера
# - (int) расстояние до места вражеского ТП
# - (int) расстояние до места доступного для союзного ТП
# - (int) расстояние до ближайшего видимого врага
# - (int) расстояние до ближайшего видимого союзника
# - (int) кол-во в команде упнутых травелов
# - (true/false) день/ночь
# - (int) радиус обзора героя
# - ([int, ...]) исходя из героя, его предметов, абилок и их прокачек рассчитать базовые статы: сила, ловкость, интеллект, армор, урон, мув спид | https://api.opendota.com/api/heroStats; https://api.opendota.com/api/constants/items; https://api.opendota.com/api/constants/abilities; https://github.com/odota/dotaconstants/blob/master/build
# - ([[str, int], ...]) название абилки, кулдаун
# - ([[str, int], ...]) название предмета, кулдаун
# - (int) счет radiant
# - (int) счет dire
# - (str) название команды
# - (int) кд байбека
# - (int) стоимость байбека
# - (true/false) silenced
# - (true/false) stunned
# - (true/false) disarmed
# - (true/false) magicimmune
# - (true/false) hexed
# - ([str, [id, ...]...]) для каждого вражеского героя по предполагаемым соображениям его ОПАСНЫЕ ПРЕДМЕТЫ
# - (int) время

# %% [markdown]
# в парсе одоты, нужно смотреть для станнов/замедлений/баффов/тд - modifier_stunned в DOTA_COMBATLOG_MODIFIER_ADD

# %% [markdown]
# классификация предметов на опасные/сейвящие для врмени t

# %% [markdown]
# 2 отдельных + групповой
#
# регламент курсача
#
# частная: глобально: введение(цели, задачи, новизну, аналоги), 1 часть(теория, модели, данные, как согласуются), 2(практика, архитектура), вывод(покрытие введения), источники(че откуда взяли)
#
# воды нет смысла 20/30 стр
#
# можно изображения, таблицы, в тексте ссылки на это
#
#
# ------------
#
#
# май - защита+-
#
# обычно комиссия не читает, простом смотрит презу

# %% [markdown]
# 1) много данных - фильтрация на репрещентативность
# 2) умный фильтр моментов - для отбора жизни
# 3) не нужно по дрейтинг
# 4) распределение героев по мете (дальнейшие шаги, в курсаче)
# 5) эксперименты: разное разбиение данных, спектаторский/нет(что убрать, оставить)
# 6) смена раз в n сек, найти t сек
# 7) делим на квадраты
# 8) инфраструктура номер 1
# 9) уменьшение инференса
# 10) тритон под торч, тензер - харам

# %%
{"time":-1,"type":"obs","slot":4,"x":117.23511,"y":126.815674,"z":129.0,"entityleft":false,"ehandle":13665944}


как в одоте находить пленты обсов
